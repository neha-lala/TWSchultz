# %% [markdown]
# # Group Project 4 - Team T.W. Schultz

# %% [markdown]
# ### Team Members: Neha Lala (*Team Manager*), Gavin Armstrong, Dojun Kim, Samantha Wang, Daniela Salinas Gomez

# %% [markdown]
# ## **1.3 [A] Unit Test:**
# ## **1.6 [A] Construct Nutrient System:**
# ## **1.7 [A] Nutritional challenges & Policy Goal:**
# ## **1.8 [B] Policy Options**
# ## **1.9 [C] Policy Cost**
# ## **1.10 [C] Value of Technical Innovation.**
# ## **1.12 [A] Replication & Discussion**

# %% [markdown]
# ## **Project Topic & Goal:**

# %% [markdown]
# Our project focuses on analyzing the nutrition breakdown in Guatemala by region (rural or urban) and, household size. We dive deep into demand for food within the groups broken down by the specified criteria and are focused on evaluating what kinds of policies might be effective at improving outcomes for particular populations with specific regards to nutritional staples. Typically, the food people choose to eat may be quite different from the foods that people should eat, from a nutritional perspective and our policies aim at closing the bag between the current nutritional consumption levels and the recommended levels of nutrient intake.

# %% [markdown]
# ## **1.1 [A] Replicability & Documentation:**
# ### *Importing Packages*:

# %%
# !pip install python-gnupg
# !pip install eep153_tools
# !pip install CFEDemands --upgrade --pre
# !pip install xarray --upgrade
# !pip install -r requirements.txt
# !pip install eep153_tools --upgrade
# !pip install ConsumerDemands

import cfe
from eep153_tools.sheets import read_sheets
import numpy as np
import pandas as pd
from cfe.estimation import drop_columns_wo_covariance
from cfe import Regression
import matplotlib.pyplot as plt
# Out:
# Collecting python-gnupg
#   Using cached python_gnupg-0.5.2-py2.py3-none-any.whl (20 kB)
# Installing collected packages: python-gnupg
# Successfully installed python-gnupg-0.5.2
# Collecting eep153_tools
#   Using cached eep153_tools-0.12.4-py2.py3-none-any.whl (4.9 kB)
# Installing collected packages: eep153_tools
# Successfully installed eep153_tools-0.12.4
# Collecting CFEDemands
#   Using cached CFEDemands-0.6.1-py2.py3-none-any.whl (45 kB)
# Requirement already satisfied: pytest>=7.1.1 in /srv/conda/lib/python3.9/site-packages (from CFEDemands) (7.4.4)
# Collecting ray>=2.0.0
#   Using cached ray-2.11.0-cp39-cp39-manylinux2014_x86_64.whl (65.3 MB)
# Collecting xarray>=0.20.1
#   Using cached xarray-2024.3.0-py3-none-any.whl (1.1 MB)
# Requirement already satisfied: scipy>=1.7.3 in /srv/conda/lib/python3.9/site-packages (from CFEDemands) (1.10.0)
# Requirement already satisfied: matplotlib>=3.5.1 in /srv/conda/lib/python3.9/site-packages (from CFEDemands) (3.7.3)
# Collecting dvc>=2.18.1
#   Using cached dvc-3.50.0-py3-none-any.whl (451 kB)
# Requirement already satisfied: joblib>=1.1.0 in /srv/conda/lib/python3.9/site-packages (from CFEDemands) (1.3.2)
# Collecting ConsumerDemands>=0.3.dev0
#   Using cached ConsumerDemands-0.4.2.dev0-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: numpy>=1.21.5 in /srv/conda/lib/python3.9/site-packages (from CFEDemands) (1.22.4)
# Requirement already satisfied: pandas>=1.4.2 in /srv/conda/lib/python3.9/site-packages (from CFEDemands) (2.2.1)
# Requirement already satisfied: statsmodels>=0.13.2 in /srv/conda/lib/python3.9/site-packages (from CFEDemands) (0.13.5)
# Requirement already satisfied: attrs>=22.2.0 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands) (23.2.0)
# Collecting platformdirs<4,>=3.1.1
#   Using cached platformdirs-3.11.0-py3-none-any.whl (17 kB)
# Collecting zc.lockfile>=1.2.1
#   Using cached zc.lockfile-3.0.post1-py3-none-any.whl (9.8 kB)
# Collecting shtab<2,>=1.3.4
#   Using cached shtab-1.7.1-py3-none-any.whl (14 kB)
# Collecting dvc-task<1,>=0.3.0
#   Using cached dvc_task-0.4.0-py3-none-any.whl (21 kB)
# Collecting shortuuid>=0.5
#   Using cached shortuuid-1.0.13-py3-none-any.whl (10 kB)
# Collecting distro>=1.3
#   Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: requests>=2.22 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands) (2.31.0)
# Collecting pathspec>=0.10.3
#   Using cached pathspec-0.12.1-py3-none-any.whl (31 kB)
# Collecting fsspec
#   Using cached fsspec-2024.3.1-py3-none-any.whl (171 kB)
# Requirement already satisfied: colorama>=0.3.9 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands) (0.4.6)
# Requirement already satisfied: pyparsing>=2.4.7 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands) (3.1.2)
# Collecting grandalf<1,>=0.7
#   Using cached grandalf-0.8-py3-none-any.whl (41 kB)
# Collecting dvc-data<3.16,>=3.15
#   Using cached dvc_data-3.15.1-py3-none-any.whl (71 kB)
# Collecting flatten-dict<1,>=0.4.1
#   Using cached flatten_dict-0.4.2-py2.py3-none-any.whl (9.7 kB)
# Collecting dvc-objects
#   Using cached dvc_objects-5.1.0-py3-none-any.whl (33 kB)
# Collecting tabulate>=0.8.7
#   Using cached tabulate-0.9.0-py3-none-any.whl (35 kB)
# Requirement already satisfied: psutil>=5.8 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands) (5.9.8)
# Collecting gto<2,>=1.6.0
#   Using cached gto-1.7.1-py3-none-any.whl (46 kB)
# Collecting dvc-render<2,>=1.0.1
#   Using cached dvc_render-1.0.2-py3-none-any.whl (22 kB)
# Collecting kombu
#   Using cached kombu-5.3.7-py3-none-any.whl (200 kB)
# Collecting pygtrie>=2.3.2
#   Using cached pygtrie-2.5.0-py3-none-any.whl (25 kB)
# Requirement already satisfied: packaging>=19 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands) (24.0)
# Collecting dvc-http>=2.29.0
#   Using cached dvc_http-2.32.0-py3-none-any.whl (12 kB)
# Collecting pydot>=1.2.4
#   Using cached pydot-2.0.0-py3-none-any.whl (22 kB)
# Requirement already satisfied: tqdm<5,>=4.63.1 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands) (4.65.0)
# Collecting dvc-studio-client<1,>=0.20
#   Using cached dvc_studio_client-0.20.0-py3-none-any.whl (16 kB)
# Collecting configobj>=5.0.6
#   Using cached configobj-5.0.8-py2.py3-none-any.whl (36 kB)
# Collecting dpath<3,>=2.1.0
#   Using cached dpath-2.1.6-py3-none-any.whl (17 kB)
# Collecting tomlkit>=0.11.1
#   Using cached tomlkit-0.12.4-py3-none-any.whl (37 kB)
# Collecting dulwich
#   Using cached dulwich-0.21.7-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (514 kB)
# Collecting funcy>=1.14
#   Using cached funcy-2.0-py2.py3-none-any.whl (30 kB)
# Collecting rich>=12
#   Using cached rich-13.7.1-py3-none-any.whl (240 kB)
# Collecting celery
#   Using cached celery-5.4.0-py3-none-any.whl (425 kB)
# Collecting scmrepo<4,>=3
#   Using cached scmrepo-3.3.1-py3-none-any.whl (73 kB)
# Requirement already satisfied: ruamel.yaml>=0.17.11 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands) (0.17.40)
# Collecting flufl.lock<8,>=5
#   Using cached flufl.lock-7.1.1-py3-none-any.whl (11 kB)
# Requirement already satisfied: networkx>=2.5 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands) (2.6.3)
# Collecting iterative-telemetry>=0.0.7
#   Using cached iterative_telemetry-0.0.8-py3-none-any.whl (10 kB)
# Collecting hydra-core>=1.1
#   Using cached hydra_core-1.3.2-py3-none-any.whl (154 kB)
# Collecting omegaconf
#   Using cached omegaconf-2.4.0.dev3-py3-none-any.whl (224 kB)
# Collecting voluptuous>=0.11.7
#   Using cached voluptuous-0.14.2-py3-none-any.whl (31 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /srv/conda/lib/python3.9/site-packages (from matplotlib>=3.5.1->CFEDemands) (1.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /srv/conda/lib/python3.9/site-packages (from matplotlib>=3.5.1->CFEDemands) (2.9.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /srv/conda/lib/python3.9/site-packages (from matplotlib>=3.5.1->CFEDemands) (6.4.0)
# Requirement already satisfied: fonttools>=4.22.0 in /srv/conda/lib/python3.9/site-packages (from matplotlib>=3.5.1->CFEDemands) (4.50.0)
# Requirement already satisfied: cycler>=0.10 in /srv/conda/lib/python3.9/site-packages (from matplotlib>=3.5.1->CFEDemands) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /srv/conda/lib/python3.9/site-packages (from matplotlib>=3.5.1->CFEDemands) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /srv/conda/lib/python3.9/site-packages (from matplotlib>=3.5.1->CFEDemands) (8.3.2)
# Requirement already satisfied: pytz>=2020.1 in /srv/conda/lib/python3.9/site-packages (from pandas>=1.4.2->CFEDemands) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /srv/conda/lib/python3.9/site-packages (from pandas>=1.4.2->CFEDemands) (2024.1)
# Requirement already satisfied: tomli>=1.0.0 in /srv/conda/lib/python3.9/site-packages (from pytest>=7.1.1->CFEDemands) (2.0.1)
# Requirement already satisfied: exceptiongroup>=1.0.0rc8 in /srv/conda/lib/python3.9/site-packages (from pytest>=7.1.1->CFEDemands) (1.2.0)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /srv/conda/lib/python3.9/site-packages (from pytest>=7.1.1->CFEDemands) (1.0.0)
# Requirement already satisfied: iniconfig in /srv/conda/lib/python3.9/site-packages (from pytest>=7.1.1->CFEDemands) (2.0.0)
# Requirement already satisfied: frozenlist in /srv/conda/lib/python3.9/site-packages (from ray>=2.0.0->CFEDemands) (1.4.1)
# Requirement already satisfied: filelock in /srv/conda/lib/python3.9/site-packages (from ray>=2.0.0->CFEDemands) (3.13.3)
# Requirement already satisfied: click>=7.0 in /srv/conda/lib/python3.9/site-packages (from ray>=2.0.0->CFEDemands) (8.1.7)
# Requirement already satisfied: pyyaml in /srv/conda/lib/python3.9/site-packages (from ray>=2.0.0->CFEDemands) (6.0.1)
# Requirement already satisfied: jsonschema in /srv/conda/lib/python3.9/site-packages (from ray>=2.0.0->CFEDemands) (4.21.1)
# Requirement already satisfied: aiosignal in /srv/conda/lib/python3.9/site-packages (from ray>=2.0.0->CFEDemands) (1.3.1)
# Collecting msgpack<2.0.0,>=1.0.0
#   Using cached msgpack-1.0.8-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (385 kB)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /srv/conda/lib/python3.9/site-packages (from ray>=2.0.0->CFEDemands) (4.25.3)
# Requirement already satisfied: patsy>=0.5.2 in /srv/conda/lib/python3.9/site-packages (from statsmodels>=0.13.2->CFEDemands) (0.5.6)
# Collecting numpy>=1.21.5
#   Using cached numpy-1.26.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
# Requirement already satisfied: six in /srv/conda/lib/python3.9/site-packages (from configobj>=5.0.6->dvc>=2.18.1->CFEDemands) (1.16.0)
# Collecting diskcache>=5.2.1
#   Using cached diskcache-5.6.3-py3-none-any.whl (45 kB)
# Collecting sqltrie<1,>=0.11.0
#   Using cached sqltrie-0.11.0-py3-none-any.whl (17 kB)
# Collecting dictdiffer>=0.8.1
#   Using cached dictdiffer-0.9.0-py2.py3-none-any.whl (16 kB)
# Collecting aiohttp-retry>=2.5.0
#   Using cached aiohttp_retry-2.8.3-py3-none-any.whl (9.8 kB)
# Collecting billiard<5.0,>=4.2.0
#   Using cached billiard-4.2.0-py3-none-any.whl (86 kB)
# Collecting click-didyoumean>=0.3.0
#   Using cached click_didyoumean-0.3.1-py3-none-any.whl (3.6 kB)
# Requirement already satisfied: click-plugins>=1.1.1 in /srv/conda/lib/python3.9/site-packages (from celery->dvc>=2.18.1->CFEDemands) (1.1.1)
# Collecting click-repl>=0.2.0
#   Using cached click_repl-0.3.0-py3-none-any.whl (10 kB)
# Collecting vine<6.0,>=5.1.0
#   Using cached vine-5.1.0-py3-none-any.whl (9.6 kB)
# Collecting atpublic>=2.3
#   Using cached atpublic-4.1.0-py3-none-any.whl (5.0 kB)
# Collecting semver>=2.13.0
#   Using cached semver-3.0.2-py3-none-any.whl (17 kB)
# Requirement already satisfied: pydantic!=2.0.0,<3,>=1.9.0 in /srv/conda/lib/python3.9/site-packages (from gto<2,>=1.6.0->dvc>=2.18.1->CFEDemands) (1.9.2)
# Requirement already satisfied: entrypoints in /srv/conda/lib/python3.9/site-packages (from gto<2,>=1.6.0->dvc>=2.18.1->CFEDemands) (0.4)
# Requirement already satisfied: typer>=0.4.1 in /srv/conda/lib/python3.9/site-packages (from gto<2,>=1.6.0->dvc>=2.18.1->CFEDemands) (0.4.2)
# Collecting antlr4-python3-runtime==4.9.*
#   Using cached antlr4_python3_runtime-4.9.3-py3-none-any.whl
# Collecting omegaconf
#   Using cached omegaconf-2.3.0-py3-none-any.whl (79 kB)
# Requirement already satisfied: zipp>=3.1.0 in /srv/conda/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib>=3.5.1->CFEDemands) (3.17.0)
# Collecting appdirs
#   Using cached appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Collecting amqp<6.0.0,>=5.1.1
#   Using cached amqp-5.2.0-py3-none-any.whl (50 kB)
# Requirement already satisfied: typing-extensions in /srv/conda/lib/python3.9/site-packages (from kombu->dvc>=2.18.1->CFEDemands) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /srv/conda/lib/python3.9/site-packages (from requests>=2.22->dvc>=2.18.1->CFEDemands) (3.1.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /srv/conda/lib/python3.9/site-packages (from requests>=2.22->dvc>=2.18.1->CFEDemands) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /srv/conda/lib/python3.9/site-packages (from requests>=2.22->dvc>=2.18.1->CFEDemands) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /srv/conda/lib/python3.9/site-packages (from requests>=2.22->dvc>=2.18.1->CFEDemands) (2022.12.7)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /srv/conda/lib/python3.9/site-packages (from rich>=12->dvc>=2.18.1->CFEDemands) (2.17.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /srv/conda/lib/python3.9/site-packages (from rich>=12->dvc>=2.18.1->CFEDemands) (3.0.0)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /srv/conda/lib/python3.9/site-packages (from ruamel.yaml>=0.17.11->dvc>=2.18.1->CFEDemands) (0.2.8)
# Collecting gitpython>3
#   Using cached GitPython-3.1.43-py3-none-any.whl (207 kB)
# Collecting pygit2>=1.14.0
#   Using cached pygit2-1.14.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.1 MB)
# Collecting asyncssh<3,>=2.13.1
#   Using cached asyncssh-2.14.2-py3-none-any.whl (352 kB)
# Requirement already satisfied: setuptools in /srv/conda/lib/python3.9/site-packages (from zc.lockfile>=1.2.1->dvc>=2.18.1->CFEDemands) (59.8.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /srv/conda/lib/python3.9/site-packages (from jsonschema->ray>=2.0.0->CFEDemands) (0.18.0)
# Requirement already satisfied: referencing>=0.28.4 in /srv/conda/lib/python3.9/site-packages (from jsonschema->ray>=2.0.0->CFEDemands) (0.34.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /srv/conda/lib/python3.9/site-packages (from jsonschema->ray>=2.0.0->CFEDemands) (2023.12.1)
# Requirement already satisfied: aiohttp in /srv/conda/lib/python3.9/site-packages (from aiohttp-retry>=2.5.0->dvc-http>=2.29.0->dvc>=2.18.1->CFEDemands) (3.9.3)
# Requirement already satisfied: cryptography>=39.0 in /srv/conda/lib/python3.9/site-packages (from asyncssh<3,>=2.13.1->scmrepo<4,>=3->dvc>=2.18.1->CFEDemands) (39.0.0)
# Requirement already satisfied: prompt-toolkit>=3.0.36 in /srv/conda/lib/python3.9/site-packages (from click-repl>=0.2.0->celery->dvc>=2.18.1->CFEDemands) (3.0.42)
# Collecting gitdb<5,>=4.0.1
#   Using cached gitdb-4.0.11-py3-none-any.whl (62 kB)
# Requirement already satisfied: mdurl~=0.1 in /srv/conda/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich>=12->dvc>=2.18.1->CFEDemands) (0.1.2)
# Requirement already satisfied: cffi>=1.16.0 in /srv/conda/lib/python3.9/site-packages (from pygit2>=1.14.0->scmrepo<4,>=3->dvc>=2.18.1->CFEDemands) (1.16.0)
# Collecting orjson
#   Using cached orjson-3.10.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (140 kB)
# Requirement already satisfied: yarl<2.0,>=1.0 in /srv/conda/lib/python3.9/site-packages (from aiohttp->aiohttp-retry>=2.5.0->dvc-http>=2.29.0->dvc>=2.18.1->CFEDemands) (1.9.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in /srv/conda/lib/python3.9/site-packages (from aiohttp->aiohttp-retry>=2.5.0->dvc-http>=2.29.0->dvc>=2.18.1->CFEDemands) (6.0.5)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /srv/conda/lib/python3.9/site-packages (from aiohttp->aiohttp-retry>=2.5.0->dvc-http>=2.29.0->dvc>=2.18.1->CFEDemands) (4.0.3)
# Requirement already satisfied: pycparser in /srv/conda/lib/python3.9/site-packages (from cffi>=1.16.0->pygit2>=1.14.0->scmrepo<4,>=3->dvc>=2.18.1->CFEDemands) (2.21)
# Collecting smmap<6,>=3.0.1
#   Using cached smmap-5.0.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: wcwidth in /srv/conda/lib/python3.9/site-packages (from prompt-toolkit>=3.0.36->click-repl>=0.2.0->celery->dvc>=2.18.1->CFEDemands) (0.2.13)
# Installing collected packages: pygtrie, funcy, dictdiffer, ConsumerDemands, appdirs, antlr4-python3-runtime, zc.lockfile, voluptuous, vine, tomlkit, tabulate, smmap, shtab, shortuuid, semver, pydot, platformdirs, pathspec, orjson, omegaconf, numpy, msgpack, grandalf, fsspec, flatten-dict, dvc-render, dulwich, dpath, distro, diskcache, configobj, click-didyoumean, billiard, atpublic, sqltrie, rich, pygit2, iterative-telemetry, hydra-core, gitdb, flufl.lock, dvc-studio-client, dvc-objects, click-repl, amqp, xarray, kombu, gitpython, dvc-data, asyncssh, aiohttp-retry, scmrepo, ray, dvc-http, celery, gto, dvc-task, dvc, CFEDemands
#   Attempting uninstall: platformdirs
#     Found existing installation: platformdirs 4.2.0
#     Uninstalling platformdirs-4.2.0:
#       Successfully uninstalled platformdirs-4.2.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.22.4
#     Uninstalling numpy-1.22.4:
#       Successfully uninstalled numpy-1.22.4
#   Attempting uninstall: xarray
#     Found existing installation: xarray 0.19.0
#     Uninstalling xarray-0.19.0:
#       Successfully uninstalled xarray-0.19.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# linearmodels 0.0.0 requires setuptools-scm[toml]<9.0.0,>=8.0.0, which is not installed.
# fenics-dolfin 2019.1.0 requires pybind11==2.2.4, but you have pybind11 2.9.2 which is incompatible.
# Successfully installed CFEDemands-0.6.1 ConsumerDemands-0.4.2.dev0 aiohttp-retry-2.8.3 amqp-5.2.0 antlr4-python3-runtime-4.9.3 appdirs-1.4.4 asyncssh-2.14.2 atpublic-4.1.0 billiard-4.2.0 celery-5.4.0 click-didyoumean-0.3.1 click-repl-0.3.0 configobj-5.0.8 dictdiffer-0.9.0 diskcache-5.6.3 distro-1.9.0 dpath-2.1.6 dulwich-0.21.7 dvc-3.50.0 dvc-data-3.15.1 dvc-http-2.32.0 dvc-objects-5.1.0 dvc-render-1.0.2 dvc-studio-client-0.20.0 dvc-task-0.4.0 flatten-dict-0.4.2 flufl.lock-7.1.1 fsspec-2024.3.1 funcy-2.0 gitdb-4.0.11 gitpython-3.1.43 grandalf-0.8 gto-1.7.1 hydra-core-1.3.2 iterative-telemetry-0.0.8 kombu-5.3.7 msgpack-1.0.8 numpy-1.26.4 omegaconf-2.3.0 orjson-3.10.1 pathspec-0.12.1 platformdirs-3.11.0 pydot-2.0.0 pygit2-1.14.1 pygtrie-2.5.0 ray-2.11.0 rich-13.7.1 scmrepo-3.3.1 semver-3.0.2 shortuuid-1.0.13 shtab-1.7.1 smmap-5.0.1 sqltrie-0.11.0 tabulate-0.9.0 tomlkit-0.12.4 vine-5.1.0 voluptuous-0.14.2 xarray-2024.3.0 zc.lockfile-3.0.post1
# Requirement already satisfied: xarray in /srv/conda/lib/python3.9/site-packages (2024.3.0)
# Requirement already satisfied: pandas>=1.5 in /srv/conda/lib/python3.9/site-packages (from xarray) (2.2.1)
# Requirement already satisfied: packaging>=22 in /srv/conda/lib/python3.9/site-packages (from xarray) (24.0)
# Requirement already satisfied: numpy>=1.23 in /srv/conda/lib/python3.9/site-packages (from xarray) (1.26.4)
# Requirement already satisfied: pytz>=2020.1 in /srv/conda/lib/python3.9/site-packages (from pandas>=1.5->xarray) (2024.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /srv/conda/lib/python3.9/site-packages (from pandas>=1.5->xarray) (2.9.0)
# Requirement already satisfied: tzdata>=2022.7 in /srv/conda/lib/python3.9/site-packages (from pandas>=1.5->xarray) (2024.1)
# Requirement already satisfied: six>=1.5 in /srv/conda/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas>=1.5->xarray) (1.16.0)
# Requirement already satisfied: CFEDemands>=0.4.1 in /srv/conda/lib/python3.9/site-packages (from -r requirements.txt (line 5)) (0.6.1)
# Collecting gspread>=5.0.1
#   Using cached gspread-6.1.0-py3-none-any.whl (55 kB)
# Collecting gspread_pandas>=3.2.0
#   Using cached gspread_pandas-3.3.0-py2.py3-none-any.whl (27 kB)
# Collecting oauth2client>=4.1.3
#   Using cached oauth2client-4.1.3-py2.py3-none-any.whl (98 kB)
# Requirement already satisfied: eep153_tools>=0.11 in /srv/conda/lib/python3.9/site-packages (from -r requirements.txt (line 21)) (0.12.4)
# Requirement already satisfied: python-gnupg in /srv/conda/lib/python3.9/site-packages (from -r requirements.txt (line 22)) (0.5.2)
# Requirement already satisfied: ConsumerDemands in /srv/conda/lib/python3.9/site-packages (from -r requirements.txt (line 24)) (0.4.2.dev0)
# Requirement already satisfied: dvc>=2.18.1 in /srv/conda/lib/python3.9/site-packages (from CFEDemands>=0.4.1->-r requirements.txt (line 5)) (3.50.0)
# Requirement already satisfied: pytest>=7.1.1 in /srv/conda/lib/python3.9/site-packages (from CFEDemands>=0.4.1->-r requirements.txt (line 5)) (7.4.4)
# Requirement already satisfied: xarray>=0.20.1 in /srv/conda/lib/python3.9/site-packages (from CFEDemands>=0.4.1->-r requirements.txt (line 5)) (2024.3.0)
# Requirement already satisfied: ray>=2.0.0 in /srv/conda/lib/python3.9/site-packages (from CFEDemands>=0.4.1->-r requirements.txt (line 5)) (2.11.0)
# Requirement already satisfied: joblib>=1.1.0 in /srv/conda/lib/python3.9/site-packages (from CFEDemands>=0.4.1->-r requirements.txt (line 5)) (1.3.2)
# Requirement already satisfied: matplotlib>=3.5.1 in /srv/conda/lib/python3.9/site-packages (from CFEDemands>=0.4.1->-r requirements.txt (line 5)) (3.7.3)
# Requirement already satisfied: pandas>=1.4.2 in /srv/conda/lib/python3.9/site-packages (from CFEDemands>=0.4.1->-r requirements.txt (line 5)) (2.2.1)
# Requirement already satisfied: scipy>=1.7.3 in /srv/conda/lib/python3.9/site-packages (from CFEDemands>=0.4.1->-r requirements.txt (line 5)) (1.10.0)
# Requirement already satisfied: statsmodels>=0.13.2 in /srv/conda/lib/python3.9/site-packages (from CFEDemands>=0.4.1->-r requirements.txt (line 5)) (0.13.5)
# Requirement already satisfied: numpy>=1.21.5 in /srv/conda/lib/python3.9/site-packages (from CFEDemands>=0.4.1->-r requirements.txt (line 5)) (1.26.4)
# Collecting StrEnum==0.4.15
#   Using cached StrEnum-0.4.15-py3-none-any.whl (8.9 kB)
# Requirement already satisfied: google-auth-oauthlib>=0.4.1 in /srv/conda/lib/python3.9/site-packages (from gspread>=5.0.1->-r requirements.txt (line 7)) (0.4.5)
# Requirement already satisfied: google-auth>=1.12.0 in /srv/conda/lib/python3.9/site-packages (from gspread>=5.0.1->-r requirements.txt (line 7)) (2.29.0)
# Collecting gspread>=5.0.1
#   Using cached gspread-5.12.4-py3-none-any.whl (49 kB)
# Requirement already satisfied: decorator in /srv/conda/lib/python3.9/site-packages (from gspread_pandas>=3.2.0->-r requirements.txt (line 8)) (5.0.9)
# Requirement already satisfied: httplib2>=0.9.1 in /srv/conda/lib/python3.9/site-packages (from oauth2client>=4.1.3->-r requirements.txt (line 11)) (0.22.0)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /srv/conda/lib/python3.9/site-packages (from oauth2client>=4.1.3->-r requirements.txt (line 11)) (0.4.0)
# Requirement already satisfied: pyasn1>=0.1.7 in /srv/conda/lib/python3.9/site-packages (from oauth2client>=4.1.3->-r requirements.txt (line 11)) (0.6.0)
# Requirement already satisfied: rsa>=3.1.4 in /srv/conda/lib/python3.9/site-packages (from oauth2client>=4.1.3->-r requirements.txt (line 11)) (4.9)
# Requirement already satisfied: six>=1.6.1 in /srv/conda/lib/python3.9/site-packages (from oauth2client>=4.1.3->-r requirements.txt (line 11)) (1.16.0)
# Requirement already satisfied: funcy>=1.14 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (2.0)
# Requirement already satisfied: pydot>=1.2.4 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (2.0.0)
# Requirement already satisfied: voluptuous>=0.11.7 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (0.14.2)
# Requirement already satisfied: dvc-render<2,>=1.0.1 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (1.0.2)
# Requirement already satisfied: ruamel.yaml>=0.17.11 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (0.17.40)
# Requirement already satisfied: colorama>=0.3.9 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (0.4.6)
# Requirement already satisfied: kombu in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (5.3.7)
# Requirement already satisfied: flatten-dict<1,>=0.4.1 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (0.4.2)
# Requirement already satisfied: dvc-studio-client<1,>=0.20 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (0.20.0)
# Requirement already satisfied: dulwich in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (0.21.7)
# Requirement already satisfied: gto<2,>=1.6.0 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (1.7.1)
# Requirement already satisfied: scmrepo<4,>=3 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (3.3.1)
# Requirement already satisfied: hydra-core>=1.1 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (1.3.2)
# Requirement already satisfied: distro>=1.3 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (1.9.0)
# Requirement already satisfied: psutil>=5.8 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (5.9.8)
# Requirement already satisfied: rich>=12 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (13.7.1)
# Requirement already satisfied: attrs>=22.2.0 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (23.2.0)
# Requirement already satisfied: dvc-objects in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (5.1.0)
# Requirement already satisfied: pyparsing>=2.4.7 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (3.1.2)
# Requirement already satisfied: packaging>=19 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (24.0)
# Requirement already satisfied: dvc-http>=2.29.0 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (2.32.0)
# Requirement already satisfied: pathspec>=0.10.3 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (0.12.1)
# Requirement already satisfied: networkx>=2.5 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (2.6.3)
# Requirement already satisfied: omegaconf in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (2.3.0)
# Requirement already satisfied: pygtrie>=2.3.2 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (2.5.0)
# Requirement already satisfied: tabulate>=0.8.7 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (0.9.0)
# Requirement already satisfied: celery in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (5.4.0)
# Requirement already satisfied: requests>=2.22 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (2.31.0)
# Requirement already satisfied: zc.lockfile>=1.2.1 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (3.0.post1)
# Requirement already satisfied: platformdirs<4,>=3.1.1 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (3.11.0)
# Requirement already satisfied: shortuuid>=0.5 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (1.0.13)
# Requirement already satisfied: dvc-data<3.16,>=3.15 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (3.15.1)
# Requirement already satisfied: tqdm<5,>=4.63.1 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (4.65.0)
# Requirement already satisfied: tomlkit>=0.11.1 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (0.12.4)
# Requirement already satisfied: configobj>=5.0.6 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (5.0.8)
# Requirement already satisfied: dvc-task<1,>=0.3.0 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (0.4.0)
# Requirement already satisfied: dpath<3,>=2.1.0 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (2.1.6)
# Requirement already satisfied: fsspec in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (2024.3.1)
# Requirement already satisfied: grandalf<1,>=0.7 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (0.8)
# Requirement already satisfied: shtab<2,>=1.3.4 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (1.7.1)
# Requirement already satisfied: iterative-telemetry>=0.0.7 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (0.0.8)
# Requirement already satisfied: flufl.lock<8,>=5 in /srv/conda/lib/python3.9/site-packages (from dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (7.1.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /srv/conda/lib/python3.9/site-packages (from google-auth>=1.12.0->gspread>=5.0.1->-r requirements.txt (line 7)) (5.3.3)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /srv/conda/lib/python3.9/site-packages (from google-auth-oauthlib>=0.4.1->gspread>=5.0.1->-r requirements.txt (line 7)) (2.0.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /srv/conda/lib/python3.9/site-packages (from matplotlib>=3.5.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /srv/conda/lib/python3.9/site-packages (from matplotlib>=3.5.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (8.3.2)
# Requirement already satisfied: contourpy>=1.0.1 in /srv/conda/lib/python3.9/site-packages (from matplotlib>=3.5.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (1.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /srv/conda/lib/python3.9/site-packages (from matplotlib>=3.5.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (2.9.0)
# Requirement already satisfied: fonttools>=4.22.0 in /srv/conda/lib/python3.9/site-packages (from matplotlib>=3.5.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (4.50.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /srv/conda/lib/python3.9/site-packages (from matplotlib>=3.5.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (6.4.0)
# Requirement already satisfied: cycler>=0.10 in /srv/conda/lib/python3.9/site-packages (from matplotlib>=3.5.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (0.12.1)
# Requirement already satisfied: tzdata>=2022.7 in /srv/conda/lib/python3.9/site-packages (from pandas>=1.4.2->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (2024.1)
# Requirement already satisfied: pytz>=2020.1 in /srv/conda/lib/python3.9/site-packages (from pandas>=1.4.2->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (2024.1)
# Requirement already satisfied: tomli>=1.0.0 in /srv/conda/lib/python3.9/site-packages (from pytest>=7.1.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (2.0.1)
# Requirement already satisfied: exceptiongroup>=1.0.0rc8 in /srv/conda/lib/python3.9/site-packages (from pytest>=7.1.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (1.2.0)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /srv/conda/lib/python3.9/site-packages (from pytest>=7.1.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (1.0.0)
# Requirement already satisfied: iniconfig in /srv/conda/lib/python3.9/site-packages (from pytest>=7.1.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (2.0.0)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /srv/conda/lib/python3.9/site-packages (from ray>=2.0.0->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (4.25.3)
# Requirement already satisfied: pyyaml in /srv/conda/lib/python3.9/site-packages (from ray>=2.0.0->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (6.0.1)
# Requirement already satisfied: click>=7.0 in /srv/conda/lib/python3.9/site-packages (from ray>=2.0.0->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (8.1.7)
# Requirement already satisfied: jsonschema in /srv/conda/lib/python3.9/site-packages (from ray>=2.0.0->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (4.21.1)
# Requirement already satisfied: frozenlist in /srv/conda/lib/python3.9/site-packages (from ray>=2.0.0->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (1.4.1)
# Requirement already satisfied: filelock in /srv/conda/lib/python3.9/site-packages (from ray>=2.0.0->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (3.13.3)
# Requirement already satisfied: aiosignal in /srv/conda/lib/python3.9/site-packages (from ray>=2.0.0->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (1.3.1)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /srv/conda/lib/python3.9/site-packages (from ray>=2.0.0->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (1.0.8)
# Requirement already satisfied: patsy>=0.5.2 in /srv/conda/lib/python3.9/site-packages (from statsmodels>=0.13.2->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (0.5.6)
# Requirement already satisfied: diskcache>=5.2.1 in /srv/conda/lib/python3.9/site-packages (from dvc-data<3.16,>=3.15->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (5.6.3)
# Requirement already satisfied: sqltrie<1,>=0.11.0 in /srv/conda/lib/python3.9/site-packages (from dvc-data<3.16,>=3.15->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (0.11.0)
# Requirement already satisfied: dictdiffer>=0.8.1 in /srv/conda/lib/python3.9/site-packages (from dvc-data<3.16,>=3.15->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (0.9.0)
# Requirement already satisfied: aiohttp-retry>=2.5.0 in /srv/conda/lib/python3.9/site-packages (from dvc-http>=2.29.0->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (2.8.3)
# Requirement already satisfied: click-plugins>=1.1.1 in /srv/conda/lib/python3.9/site-packages (from celery->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (1.1.1)
# Requirement already satisfied: vine<6.0,>=5.1.0 in /srv/conda/lib/python3.9/site-packages (from celery->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (5.1.0)
# Requirement already satisfied: click-didyoumean>=0.3.0 in /srv/conda/lib/python3.9/site-packages (from celery->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (0.3.1)
# Requirement already satisfied: click-repl>=0.2.0 in /srv/conda/lib/python3.9/site-packages (from celery->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (0.3.0)
# Requirement already satisfied: billiard<5.0,>=4.2.0 in /srv/conda/lib/python3.9/site-packages (from celery->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (4.2.0)
# Requirement already satisfied: atpublic>=2.3 in /srv/conda/lib/python3.9/site-packages (from flufl.lock<8,>=5->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (4.1.0)
# Requirement already satisfied: pydantic!=2.0.0,<3,>=1.9.0 in /srv/conda/lib/python3.9/site-packages (from gto<2,>=1.6.0->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (1.9.2)
# Requirement already satisfied: semver>=2.13.0 in /srv/conda/lib/python3.9/site-packages (from gto<2,>=1.6.0->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (3.0.2)
# Requirement already satisfied: entrypoints in /srv/conda/lib/python3.9/site-packages (from gto<2,>=1.6.0->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (0.4)
# Requirement already satisfied: typer>=0.4.1 in /srv/conda/lib/python3.9/site-packages (from gto<2,>=1.6.0->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (0.4.2)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /srv/conda/lib/python3.9/site-packages (from hydra-core>=1.1->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (4.9.3)
# Requirement already satisfied: zipp>=3.1.0 in /srv/conda/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib>=3.5.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (3.17.0)
# Requirement already satisfied: appdirs in /srv/conda/lib/python3.9/site-packages (from iterative-telemetry>=0.0.7->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (1.4.4)
# Requirement already satisfied: amqp<6.0.0,>=5.1.1 in /srv/conda/lib/python3.9/site-packages (from kombu->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (5.2.0)
# Requirement already satisfied: typing-extensions in /srv/conda/lib/python3.9/site-packages (from kombu->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (4.10.0)
# Requirement already satisfied: certifi>=2017.4.17 in /srv/conda/lib/python3.9/site-packages (from requests>=2.22->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (2022.12.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /srv/conda/lib/python3.9/site-packages (from requests>=2.22->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (1.26.15)
# Requirement already satisfied: charset-normalizer<4,>=2 in /srv/conda/lib/python3.9/site-packages (from requests>=2.22->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /srv/conda/lib/python3.9/site-packages (from requests>=2.22->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (3.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /srv/conda/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread>=5.0.1->-r requirements.txt (line 7)) (3.2.2)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /srv/conda/lib/python3.9/site-packages (from rich>=12->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (2.17.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /srv/conda/lib/python3.9/site-packages (from rich>=12->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (3.0.0)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /srv/conda/lib/python3.9/site-packages (from ruamel.yaml>=0.17.11->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (0.2.8)
# Requirement already satisfied: asyncssh<3,>=2.13.1 in /srv/conda/lib/python3.9/site-packages (from scmrepo<4,>=3->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (2.14.2)
# Requirement already satisfied: gitpython>3 in /srv/conda/lib/python3.9/site-packages (from scmrepo<4,>=3->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (3.1.43)
# Requirement already satisfied: pygit2>=1.14.0 in /srv/conda/lib/python3.9/site-packages (from scmrepo<4,>=3->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (1.14.1)
# Requirement already satisfied: setuptools in /srv/conda/lib/python3.9/site-packages (from zc.lockfile>=1.2.1->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (59.8.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /srv/conda/lib/python3.9/site-packages (from jsonschema->ray>=2.0.0->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /srv/conda/lib/python3.9/site-packages (from jsonschema->ray>=2.0.0->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (0.34.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /srv/conda/lib/python3.9/site-packages (from jsonschema->ray>=2.0.0->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (0.18.0)
# Requirement already satisfied: aiohttp in /srv/conda/lib/python3.9/site-packages (from aiohttp-retry>=2.5.0->dvc-http>=2.29.0->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (3.9.3)
# Requirement already satisfied: cryptography>=39.0 in /srv/conda/lib/python3.9/site-packages (from asyncssh<3,>=2.13.1->scmrepo<4,>=3->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (39.0.0)
# Requirement already satisfied: prompt-toolkit>=3.0.36 in /srv/conda/lib/python3.9/site-packages (from click-repl>=0.2.0->celery->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (3.0.42)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /srv/conda/lib/python3.9/site-packages (from gitpython>3->scmrepo<4,>=3->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (4.0.11)
# Requirement already satisfied: mdurl~=0.1 in /srv/conda/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich>=12->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (0.1.2)
# Requirement already satisfied: cffi>=1.16.0 in /srv/conda/lib/python3.9/site-packages (from pygit2>=1.14.0->scmrepo<4,>=3->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (1.16.0)
# Requirement already satisfied: orjson in /srv/conda/lib/python3.9/site-packages (from sqltrie<1,>=0.11.0->dvc-data<3.16,>=3.15->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (3.10.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /srv/conda/lib/python3.9/site-packages (from aiohttp->aiohttp-retry>=2.5.0->dvc-http>=2.29.0->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /srv/conda/lib/python3.9/site-packages (from aiohttp->aiohttp-retry>=2.5.0->dvc-http>=2.29.0->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (1.9.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in /srv/conda/lib/python3.9/site-packages (from aiohttp->aiohttp-retry>=2.5.0->dvc-http>=2.29.0->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (6.0.5)
# Requirement already satisfied: pycparser in /srv/conda/lib/python3.9/site-packages (from cffi>=1.16.0->pygit2>=1.14.0->scmrepo<4,>=3->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (2.21)
# Requirement already satisfied: smmap<6,>=3.0.1 in /srv/conda/lib/python3.9/site-packages (from gitdb<5,>=4.0.1->gitpython>3->scmrepo<4,>=3->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (5.0.1)
# Requirement already satisfied: wcwidth in /srv/conda/lib/python3.9/site-packages (from prompt-toolkit>=3.0.36->click-repl>=0.2.0->celery->dvc>=2.18.1->CFEDemands>=0.4.1->-r requirements.txt (line 5)) (0.2.13)
# Installing collected packages: oauth2client, gspread, gspread_pandas
#   Attempting uninstall: gspread
#     Found existing installation: gspread 4.0.1
#     Uninstalling gspread-4.0.1:
#       Successfully uninstalled gspread-4.0.1
#   Attempting uninstall: gspread_pandas
#     Found existing installation: gspread-pandas 2.3.0
#     Uninstalling gspread-pandas-2.3.0:
#       Successfully uninstalled gspread-pandas-2.3.0
# Successfully installed gspread-5.12.4 gspread_pandas-3.3.0 oauth2client-4.1.3
# Requirement already satisfied: eep153_tools in /srv/conda/lib/python3.9/site-packages (0.12.4)
# Requirement already satisfied: ConsumerDemands in /srv/conda/lib/python3.9/site-packages (0.4.2.dev0)

# %% [markdown]
# ## **1.4 [A] Choice of a dataset:**

# %%
url = 'https://docs.google.com/spreadsheets/d/1YupX14TogoubSrlHtG9OgfBdKUhsss29L63mcNDNCUo/'

guatemala_prices = read_sheets(url,sheet='Food Prices',nheaders=2)
guatemala_fct = read_sheets(url,sheet='FCT')
guatemala_hhc = read_sheets(url,sheet='Household Characteristics')
guatemala_expenditures = read_sheets(url,sheet='Food Expenditures')
price = guatemala_prices
fct = guatemala_fct
hhc = guatemala_hhc
expen = guatemala_expenditures

# %%
def clean_multiindex_df(df):
    # If the columns are a MultiIndex, join them with an underscore, otherwise just strip them
    if isinstance(df.columns, pd.MultiIndex):
        df.columns = ['_'.join(map(str, col)).strip() for col in df.columns.values]
    else:
        df.columns = [col.strip() for col in df.columns.tolist()]

    # Remove duplicated columns
    df = df.loc[:, ~df.columns.duplicated(keep='first')]

    # Drop columns that start with 'Unnamed'
    df = df.drop([col for col in df.columns if col.startswith('Unnamed')], axis=1)

    # Remove duplicated rows
    df = df.loc[~df.index.duplicated(), :]

    return df

# Clean the DataFrames with MultiIndex columns
price_cleaned = clean_multiindex_df(price)
fct_cleaned = clean_multiindex_df(fct)
hhc_cleaned = clean_multiindex_df(hhc)
expen_cleaned = clean_multiindex_df(expen)

# %%
import numpy as np
if 'm' not in expen.columns:
    expen_cleaned['m'] = 1

expen = expen_cleaned.set_index(['i','t','m'])
expen.columns.name = 'j'

expen = expen.apply(lambda x: pd.to_numeric(x,errors='coerce'))
expen = expen.replace(0,np.nan)

hhc = hhc_cleaned
if 'm' not in hhc.columns:
    hhc['m'] = 1

hhc = hhc.set_index(['i','t','m'])
hhc.columns.name = 'j'

hhc = hhc.apply(lambda x: pd.to_numeric(x,errors='coerce'))

q = price_cleaned
if 'm' not in q.columns:
    q['m'] = 1

q = q.apply(lambda x: pd.to_numeric(x,errors='coerce'))
q = q.replace(0,np.nan)

fct.index.name = 'n'

fct = fct.apply(lambda x: pd.to_numeric(x,errors='coerce'))

# %%
expen.head()
# Out:
# j                        Cooking Oil  Water (bottle)  Avocado  Mineral Water  \
# i    t    m
# 1    2000 Metropolitana          7.5            20.0      5.0           6.00
# 10   2000 Metropolitana         15.0            15.0     30.0            NaN
# 100  2000 Metropolitana         13.0            10.5      NaN          16.00
# 1000 2000 Central                9.5            10.0      NaN            NaN
# 1001 2000 Central               10.0            20.0      5.0           7.75
#
# j                        Garlic  Mushrooms  Celery  Rice  Peas  Corn Atole  \
# i    t    m
# 1    2000 Metropolitana    1.00        NaN     2.0   5.0   NaN         NaN
# 10   2000 Metropolitana    2.00       20.0     2.0  10.0   NaN         NaN
# 100  2000 Metropolitana    0.25        NaN     2.0   6.5   NaN         2.0
# 1000 2000 Central          1.50        NaN     1.5  10.0   NaN         NaN
# 1001 2000 Central          1.00        NaN     2.0   5.0   2.0         4.0
#
# j                        ...   Tea  Tomatoes  Tortillas  Tostadas  \
# i    t    m              ...
# 1    2000 Metropolitana  ...   7.0       9.0       60.0       NaN
# 10   2000 Metropolitana  ...   8.5      14.0       30.0       NaN
# 100  2000 Metropolitana  ...   NaN       2.5        4.0       NaN
# 1000 2000 Central        ...   NaN       9.0       60.0       NaN
# 1001 2000 Central        ...  22.0       6.0       37.5       NaN
#
# j                        Beef Entrails  Chicken Giblets  Yogurt  Yucca  \
# i    t    m
# 1    2000 Metropolitana            NaN             21.0     NaN    NaN
# 10   2000 Metropolitana           30.0             12.5     NaN    NaN
# 100  2000 Metropolitana           16.0              NaN     NaN    NaN
# 1000 2000 Central                  NaN              NaN     NaN    NaN
# 1001 2000 Central                 12.0              NaN     NaN    1.0
#
# j                        Carrots  Leafcutter Ants and Other Insect
# i    t    m
# 1    2000 Metropolitana      3.6                               NaN
# 10   2000 Metropolitana      7.5                               NaN
# 100  2000 Metropolitana      3.0                               NaN
# 1000 2000 Central            6.0                               NaN
# 1001 2000 Central            3.5                               NaN
#
# [5 rows x 96 columns]

# %%
hhc.head()
# Out:
# j                     Males 00-03  Females 00-03  Males 04-08  Females 04-08  \
# i t    m
# 1 2000 Metropolitana            0              1            0              0
# 2 2000 Metropolitana            0              0            0              0
# 3 2000 Metropolitana            0              0            0              0
# 4 2000 Metropolitana            0              0            0              0
# 5 2000 Metropolitana            0              0            1              0
#
# j                     Males 09-13  Females 09-13  Males 14-18  Females 14-18  \
# i t    m
# 1 2000 Metropolitana            0              0            0              0
# 2 2000 Metropolitana            0              0            0              0
# 3 2000 Metropolitana            2              0            0              0
# 4 2000 Metropolitana            0              0            0              0
# 5 2000 Metropolitana            0              0            0              0
#
# j                     Males 19-30  Females 19-30  Males 31-50  Females 31-50  \
# i t    m
# 1 2000 Metropolitana            1              1            0              1
# 2 2000 Metropolitana            0              0            1              0
# 3 2000 Metropolitana            1              0            1              1
# 4 2000 Metropolitana            0              0            0              0
# 5 2000 Metropolitana            0              0            1              1
#
# j                     Males 51-99  Females 51-99  log HSize  Rural
# i t    m
# 1 2000 Metropolitana            0              0   1.386294      0
# 2 2000 Metropolitana            1              1   1.098612      0
# 3 2000 Metropolitana            1              0   1.791759      0
# 4 2000 Metropolitana            0              1   0.000000      0
# 5 2000 Metropolitana            0              0   1.098612      0

# %%
q.head()
# Out:
#                     2000_Central  2000_Metropolitana  2000_Noroccidente  \
# j              u
# Cooking Oil    lbs      5.010737            5.368647           4.545454
# Water (bottle) lbs      0.454545            0.240500           0.240500
# Avocado        lbs      1.865672            3.544776           1.492537
# Mineral Water  lbs      2.750779            2.731270           3.209243
# Garlic         lbs      4.545455            4.545455           4.545455
#
#                     2000_Nororiente  2000_Norte  2000_Peten  \
# j              u
# Cooking Oil    lbs         4.563468    5.368647    5.000000
# Water (bottle) lbs         0.264550    0.240500    0.300625
# Avocado        lbs         3.731343    1.492537    1.492537
# Mineral Water  lbs         3.209243    3.209243    3.851091
# Garlic         lbs         9.090909    3.787879    9.090909
#
#                     2000_Suroccidente  2000_Suroriente  m
# j              u
# Cooking Oil    lbs           3.863636         5.368647  1
# Water (bottle) lbs           0.245700         0.288600  1
# Avocado        lbs           1.492537         2.985075  1
# Mineral Water  lbs           3.209243         3.209243  1
# Garlic         lbs           4.545455         4.545455  1

# %%
fct.head()
# Out:
#     j  2000   Code  Nutrient   Agua  Energía  Proteina  Grasa Total  \
# n
# 0 NaN   NaN  16029       NaN   0.00      884      0.00       100.00
# 1 NaN   NaN   3046       NaN  69.80      168     17.89         9.21
# 2 NaN   NaN  11005       NaN  73.23      160      2.00        14.66
# 3 NaN   NaN  17016       NaN  87.60       48      0.00         0.00
# 4 NaN   NaN  11006       NaN  63.80      134      5.30         0.20
#
#    Carbo-hidratos  Fibra Diet. total  ...  Colesterol  Potasio  Sodio  Zinc  \
# n                                     ...
# 0            0.00                0.0  ...           0        0      0  0.00
# 1            2.13                0.0  ...         240      226     77  3.01
# 2            8.53                6.7  ...           0      485      7  0.64
# 3           12.30                0.0  ...           0        2     12  0.10
# 4           29.30                0.0  ...           0      529     19  1.00
#
#    Magnesio  Vit. B6  Vit. B12  Ac. Fólico  Folato Equiv. FD  \
# n
# 0         0     0.00      0.00           0                 0
# 1        18     0.52     10.83           0               350
# 2        29     0.26      0.00           0                81
# 3         1     0.00      0.00           0                 0
# 4         0     0.00      0.00           3                 0
#
#    Fracción Comestible
# n
# 0                 1.00
# 1                 1.00
# 2                 0.74
# 3                 1.00
# 4                 0.94
#
# [5 rows x 32 columns]

# %% [markdown]
# ## **1.5 [A] Estimate Demand System:**

# %%
import cfe

result = cfe.Regression(y=np.log(expen.stack()),d=hhc)

result.get_beta().sort_values(ascending=False)
result.to_pickle('./foo.pickle')
result = cfe.read_pickle('foo.pickle')
result.predicted_expenditures()
# Out:
# i     t     m              j
# 1     2000  Metropolitana  Avocado             7.131134
#                            Bananas            16.368000
#                            Beans               9.351316
#                            Beef              102.055889
#                            Beef Entrails      13.977229
#                                                 ...
# 7276  2000  Suroriente     Tostadas            8.796111
#                            Water (bottle)      9.580927
#                            Watermelon          7.935121
#                            Wheat Flour         4.943983
#                            Yucca               3.456677
# Length: 515736, dtype: float64
